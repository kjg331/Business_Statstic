# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Building IMDB Movie Data

# %% [markdown]
# ## IMDb Datasets
#
# Subsets of IMDb data are available for access to customers for personal and non-commercial use. You can hold local copies of this data, and it is subject to our terms and conditions. Please refer to the Non-Commercial Licensing and copyright/license and verify compliance.
#
# ## Data Location
#
# The dataset files can be accessed and downloaded from https://datasets.imdbws.com/. The data is refreshed daily.
#
# IMDb Dataset Details
#
# Each dataset is contained in a gzipped, tab-separated-values (TSV) formatted file in the UTF-8 character set. The first line in each file contains headers that describe what is in each column. A ‘\N’ is used to denote that a particular field is missing or null for that title/name. The available datasets are as follows:
#
# #### title.akas.tsv.gz - Contains the following information for titles:
#
# - titleId (string) - a tconst, an alphanumeric unique identifier of the title
# - ordering (integer) – a number to uniquely identify rows for a given titleId
# - title (string) – the localized title
# - region (string) - the region for this version of the title
# - language (string) - the language of the title
# - types (array) - Enumerated set of attributes for this alternative title. One or more of the following: "alternative", "dvd", "festival", "tv", "video", "working", "original", "imdbDisplay". New values may be added in the future without warning
# - attributes (array) - Additional terms to describe this alternative title, not enumerated
# - isOriginalTitle (boolean) – 0: not original title; 1: original title
#
# #### title.basics.tsv.gz - Contains the following information for titles:
# - tconst (string) - alphanumeric unique identifier of the title
# - titleType (string) – the type/format of the title (e.g. movie, short, tvseries, tvepisode, video, etc)
# - primaryTitle (string) – the more popular title / the title used by the filmmakers on promotional materials at the point of release
# - originalTitle (string) - original title, in the original language
# - isAdult (boolean) - 0: non-adult title; 1: adult title
# - startYear (YYYY) – represents the release year of a title. In the case of TV Series, it is the series start year
# - endYear (YYYY) – TV Series end year. ‘\N’ for all other title types
# - runtimeMinutes – primary runtime of the title, in minutes
# - genres (string array) – includes up to three genres associated with the title
#
# #### title.crew.tsv.gz – Contains the director and writer information for all the titles in IMDb. Fields include:
# - tconst (string) - alphanumeric unique identifier of the title
# - directors (array of nconsts) - director(s) of the given title
# - writers (array of nconsts) – writer(s) of the given title
#
# #### title.episode.tsv.gz – Contains the tv episode information. Fields include:
# - tconst (string) - alphanumeric identifier of episode
# - parentTconst (string) - alphanumeric identifier of the parent TV Series
# - seasonNumber (integer) – season number the episode belongs to
# - episodeNumber (integer) – episode number of the tconst in the TV series
# - title.principals.tsv.gz – Contains the principal cast/crew for titles
# - tconst (string) - alphanumeric unique identifier of the title
# - ordering (integer) – a number to uniquely identify rows for a given titleId
# - nconst (string) - alphanumeric unique identifier of the name/person
# - category (string) - the category of job that person was in
# - job (string) - the specific job title if applicable, else '\N'
# - characters (string) - the name of the character played if applicable, else '\N'
#
# #### title.ratings.tsv.gz – Contains the IMDb rating and votes information for titles
# - tconst (string) - alphanumeric unique identifier of the title
# - averageRating – weighted average of all the individual user ratings
# - numVotes - number of votes the title has received
#
# #### name.basics.tsv.gz – Contains the following information for names:
# - nconst (string) - alphanumeric unique identifier of the name/person
# - primaryName (string)– name by which the person is most often credited
# - birthYear – in YYYY format
# - deathYear – in YYYY format if applicable, else '\N'
# - primaryProfession (array of strings)– the top-3 professions of the person
# - knownForTitles (array of tconsts) – titles the person is known for

# %% [markdown]
# ### 1) Data from Kaggle
#
# https://www.kaggle.com/stefanoleone992/imdb-extensive-dataset?select=IMDb+title_principals.csv
#
# #### Acknowledgements
# - Data has been scraped from the publicly available website https://www.imdb.com.
# - All the movies with more than 100 votes have been scraped as of 01/01/2020.

# %%
# data scrapped 202001
ratings_202001 = pd.read_csv("IMDb_ratings_202001.csv")
names_202001 = pd.read_csv("IMDb_movies_202001.csv")
# Out:
# C:\Users\kjkoo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
names_202001.shape
# Out:
# (85855, 22)

# %%
ratings_202001.shape
# Out:
# (85855, 49)

# %%
imdb_data_merge_202001 = pd.merge(names_202001,ratings_202001,on='imdb_title_id')
imdb_data_merge_202001.head()
imdb_data_merge_202001.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics', 'weighted_average_vote',
#        'total_votes', 'mean_vote', 'median_vote', 'votes_10', 'votes_9',
#        'votes_8', 'votes_7', 'votes_6', 'votes_5', 'votes_4', 'votes_3',
#        'votes_2', 'votes_1', 'allgenders_0age_avg_vote',
#        'allgenders_0age_votes', 'allgenders_18age_avg_vote',
#        'allgenders_18age_votes', 'allgenders_30age_avg_vote',
#        'allgenders_30age_votes', 'allgenders_45age_avg_vote',
#        'allgenders_45age_votes', 'males_allages_avg_vote',
#        'males_allages_votes', 'males_0age_avg_vote', 'males_0age_votes',
#        'males_18age_avg_vote', 'males_18age_votes', 'males_30age_avg_vote',
#        'males_30age_votes', 'males_45age_avg_vote', 'males_45age_votes',
#        'females_allages_avg_vote', 'females_allages_votes',
#        'females_0age_avg_vote', 'females_0age_votes', 'females_18age_avg_vote',
#        'females_18age_votes', 'females_30age_avg_vote', 'females_30age_votes',
#        'females_45age_avg_vote', 'females_45age_votes',
#        'top1000_voters_rating', 'top1000_voters_votes', 'us_voters_rating',
#        'us_voters_votes', 'non_us_voters_rating', 'non_us_voters_votes'],
#       dtype='object')

# %%
imdb_data_202001 = imdb_data_merge_202001[['imdb_title_id','title','original_title','year','date_published','genre','duration','country',
                'language','director','writer','production_company','actors','description','avg_vote','votes',
                'budget','worlwide_gross_income',]].copy()

# %%
imdb_data_202001.to_csv("IMDB_DATA_202001.csv", index=False, encoding='UTF-8')

# %%
imdb_data_202001.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  \
# 0     None                      Alexander Black
# 1     None                         Charles Tait
# 2      NaN                            Urban Gad
# 3  English                   Charles L. Gaskill
# 4  Italian  Francesco Bertolini, Adolfo Padovan
#
#                                   writer             production_company  \
# 0                        Alexander Black     Alexander Black Photoplays
# 1                           Charles Tait                 J. and N. Tait
# 2  Urban Gad, Gebhard Schätzler-Perasini                       Fotorama
# 3                       Victorien Sardou  Helen Gardner Picture Players
# 4                        Dante Alighieri                    Milano Film
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description  avg_vote  votes  \
# 0  The adventures of a female reporter in the 1890s.       5.9    154
# 1  True story of notorious Australian outlaw Ned ...       6.1    589
# 2  Two men of high rank are both wooing the beaut...       5.8    188
# 3  The fabled queen of Egypt's affair with Roman ...       5.2    446
# 4  Loosely adapted from Dante's Divine Comedy and...       7.0   2237
#
#     budget worlwide_gross_income
# 0      NaN                   NaN
# 1   $ 2250                   NaN
# 2      NaN                   NaN
# 3  $ 45000                   NaN
# 4      NaN                   NaN

# %% [markdown]
# ### 2) Directly scrap data from IMdb
#
# #### Acknowledgements
# - Data has been scraped from the publicly available website https://www.imdb.com.
# - All the movies with more than 100 votes have been scraped as of 10/16/2020.

# %%
# Data scrapped 202110
name_202110 = pd.read_csv('IMDB_movies_20211015/data.tsv', header=0, sep='\t', quotechar='"', error_bad_lines=False, encoding='UTF-8')
ratings_202110 = pd.read_csv('IMDB_ratings_20211015/data.tsv', header=0, sep='\t', quotechar='"', error_bad_lines=False, encoding='UTF-8')
basic_202110 = pd.read_csv('IMDB_movies_20211015/basic.tsv', header=0, sep='\t', quotechar='"', error_bad_lines=False, encoding='UTF-8')
crews_202110 = pd.read_csv('IMDB_movies_20211015/crew.tsv', header=0, sep='\t', quotechar='"', error_bad_lines=False, encoding='UTF-8')
crew_names_202110 = pd.read_csv('IMDB_movies_20211015/name.tsv', header=0, sep='\t', quotechar='"', error_bad_lines=False, encoding='UTF-8')
# Out:
# C:\Users\kjkoo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\kjkoo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
names_202110.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
ratings_202110.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1827
# 1  tt0000002            6.0       233
# 2  tt0000003            6.5      1581
# 3  tt0000004            6.1       151
# 4  tt0000005            6.2      2404

# %%
basic_202110.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
names_202110.rename(columns={'titleId':'imdb_title_id'},inplace=True)
ratings_202110.rename(columns={'tconst':'imdb_title_id'},inplace=True)

# %%
names_202110.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
ratings_202110.head()
# Out:
#   imdb_title_id  averageRating  numVotes
# 0     tt0000001            5.7      1827
# 1     tt0000002            6.0       233
# 2     tt0000003            6.5      1581
# 3     tt0000004            6.1       151
# 4     tt0000005            6.2      2404

# %%
basic_202110 = basic_202110[['tconst', 'primaryTitle', 'originalTitle', 'isAdult', 'startYear', 
                             'runtimeMinutes','genres']]
basic_202110
# Out:
#             tconst               primaryTitle              originalTitle  \
# 0        tt0000001                 Carmencita                 Carmencita
# 1        tt0000002     Le clown et ses chiens     Le clown et ses chiens
# 2        tt0000003             Pauvre Pierrot             Pauvre Pierrot
# 3        tt0000004                Un bon bock                Un bon bock
# 4        tt0000005           Blacksmith Scene           Blacksmith Scene
# ...            ...                        ...                        ...
# 8357579  tt9916848              Episode #3.17              Episode #3.17
# 8357580  tt9916850              Episode #3.19              Episode #3.19
# 8357581  tt9916852              Episode #3.20              Episode #3.20
# 8357582  tt9916856                   The Wind                   The Wind
# 8357583  tt9916880  Horrid Henry Knows It All  Horrid Henry Knows It All
#
#         isAdult startYear runtimeMinutes                      genres
# 0             0      1894              1           Documentary,Short
# 1             0      1892              5             Animation,Short
# 2             0      1892              4    Animation,Comedy,Romance
# 3             0      1892             12             Animation,Short
# 4             0      1893              1                Comedy,Short
# ...         ...       ...            ...                         ...
# 8357579       0      2010             \N         Action,Drama,Family
# 8357580       0      2010             \N         Action,Drama,Family
# 8357581       0      2010             \N         Action,Drama,Family
# 8357582       0      2015             27                       Short
# 8357583       0      2014             10  Adventure,Animation,Comedy
#
# [8357584 rows x 7 columns]

# %%
basic_202110.rename(columns={'tconst':'imdb_title_id'},inplace=True)
basic_202110
# Out:
#         imdb_title_id               primaryTitle              originalTitle  \
# 0           tt0000001                 Carmencita                 Carmencita
# 1           tt0000002     Le clown et ses chiens     Le clown et ses chiens
# 2           tt0000003             Pauvre Pierrot             Pauvre Pierrot
# 3           tt0000004                Un bon bock                Un bon bock
# 4           tt0000005           Blacksmith Scene           Blacksmith Scene
# ...               ...                        ...                        ...
# 8357579     tt9916848              Episode #3.17              Episode #3.17
# 8357580     tt9916850              Episode #3.19              Episode #3.19
# 8357581     tt9916852              Episode #3.20              Episode #3.20
# 8357582     tt9916856                   The Wind                   The Wind
# 8357583     tt9916880  Horrid Henry Knows It All  Horrid Henry Knows It All
#
#         isAdult startYear runtimeMinutes                      genres
# 0             0      1894              1           Documentary,Short
# 1             0      1892              5             Animation,Short
# 2             0      1892              4    Animation,Comedy,Romance
# 3             0      1892             12             Animation,Short
# 4             0      1893              1                Comedy,Short
# ...         ...       ...            ...                         ...
# 8357579       0      2010             \N         Action,Drama,Family
# 8357580       0      2010             \N         Action,Drama,Family
# 8357581       0      2010             \N         Action,Drama,Family
# 8357582       0      2015             27                       Short
# 8357583       0      2014             10  Adventure,Animation,Comedy
#
# [8357584 rows x 7 columns]

# %%
# name + basic

merge_1 = pd.merge(names_202110, basic_202110, how = 'left', on = 'imdb_title_id')

# %%
# choose the movies numVotes over 100

ratings_202110 = ratings_202110[ratings_202110.numVotes > 100]

# %%
# name + basic + rating

merge_2 = pd.merge(ratings_202110, merge_1,how='left', on = 'imdb_title_id')
merge_2 = merge_2[merge_2.isOriginalTitle == '1']
merge_2.shape
# Out:
# (135794, 16)

# %%
# first save point

imdb_dat_202110 = merge_2.copy()
imdb_dat_202110.to_csv("imdb_data_202110.csv", index=False, encoding='UTF-8')

# %% [markdown]
# ## Combining data of 202001, 202110
#
# #### Condition of data
#
# - We use movie data released after 2000, votes > 100

# %%
## Combine 202001 + 202110
imdb_data_202001 = pd.read_csv('imdb_data_202001.csv')
imdb_data_202001.columns
# Out:
# C:\Users\kjkoo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'worlwide_gross_income'],
#       dtype='object')

# %%
imdb_data_202001['director_1'] = imdb_data_202001['director'].str.split(',').str[0]
imdb_data_202001['director_2'] = imdb_data_202001['director'].str.split(',').str[1]
imdb_data_202001['writer_1'] = imdb_data_202001['writer'].str.split(',').str[0]
imdb_data_202001['writer_2'] = imdb_data_202001['writer'].str.split(',').str[1]

# %%
imdb_data_202001['year'].replace('TV Movie 2019',2019, inplace=True)

# %%
imdb_data_202001 = imdb_data_202001[imdb_data_202001['year'].astype('int') >= 2000]

# %%
imdb_data_202001.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'genre', 'duration',
#        'country', 'language', 'director_1', 'director_2', 'writer_1',
#        'writer_2', 'actors', 'avg_vote', 'votes', 'budget',
#        'worlwide_gross_income'],
#       dtype='object')

# %%
imdb_data_202001 = imdb_data_202001[['imdb_title_id','title','original_title','year','genre','duration','country','language',
                 'director_1','director_2','writer_1','writer_2','actors','avg_vote','votes','budget',
                 'worlwide_gross_income']]

# %%
imdb_data_202110 = pd.read_csv("imdb_data_202110.csv")
imdb_data_202110.columns
# Out:
# C:\Users\kjkoo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Index(['imdb_title_id', 'averageRating', 'numVotes', 'ordering', 'title',
#        'region', 'language', 'types', 'attributes', 'isOriginalTitle',
#        'primaryTitle', 'originalTitle', 'isAdult', 'startYear',
#        'runtimeMinutes', 'genres', 'director_1', 'director_2', 'writer_1',
#        'writer_2', 'tconst', 'primaryName'],
#       dtype='object')

# %%
imdb_data_202110 = imdb_data_202110[['imdb_title_id','title','originalTitle','startYear','genres','runtimeMinutes','region',
                 'language','isAdult','director_1','director_2','writer_1','writer_2','primaryName','averageRating'
                  ,'numVotes']]

# %%
imdb_data_202110['startYear'].replace('\\N',0,inplace=True)
# Out:
# C:\Users\kjkoo\anaconda3\lib\site-packages\pandas\core\series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
imdb_data_202110 = imdb_data_202110[imdb_data_202110['startYear'].astype("int") >= 2000]

# %%
imdb_data_202110.columns = ['imdb_title_id','title','original_title','year','genre','duration',
                           'country','language','isAdult','director_1','director_2','writer_1','writer_2',
                           'actors','avg_vote','votes']

# %%
imdb_data_202110.to_csv("imdb_data_202110_fin.csv",index=False)
imdb_data_202001.to_csv('imdb_data_202001_fin.csv',index=False)

# %%
imdb_combined_data = pd.merge(imdb_data_202001,imdb_data_202110, on='imdb_title_id', how='right', 
                              suffixes=('_202001','_202110'))
imdb_combined_data
# Out:
#       imdb_title_id               title_202001      original_title_202001  \
# 0         tt0035423             Kate & Leopold             Kate & Leopold
# 1         tt0036177                        NaN                        NaN
# 2         tt0062336                        NaN                        NaN
# 3         tt0065047                        NaN                        NaN
# 4         tt0067230                        NaN                        NaN
# ...             ...                        ...                        ...
# 81706     tt7274806  Kaashi in Search of Ganga  Kaashi in Search of Ganga
# 81707     tt7275232        Welcome to New York        Welcome to New York
# 81708     tt7275352                      Demon                      Demon
# 81709     tt7275816                       Wuff                       Wuff
# 81710     tt7275822         Klassentreffen 1.0         Klassentreffen 1.0
#
#       year_202001              genre_202001  duration_202001 country_202001  \
# 0            2001  Comedy, Fantasy, Romance            118.0            USA
# 1             NaN                       NaN              NaN            NaN
# 2             NaN                       NaN              NaN            NaN
# 3             NaN                       NaN              NaN            NaN
# 4             NaN                       NaN              NaN            NaN
# ...           ...                       ...              ...            ...
# 81706        2018                  Thriller            125.0          India
# 81707        2018             Comedy, Drama            118.0          India
# 81708        2017                    Horror             70.0            USA
# 81709        2018    Comedy, Drama, Romance            114.0        Germany
# 81710        2018             Comedy, Drama            127.0        Germany
#
#        language_202001 director_1_202001 director_2_202001  ...  \
# 0      English, French     James Mangold               NaN  ...
# 1                  NaN               NaN               NaN  ...
# 2                  NaN               NaN               NaN  ...
# 3                  NaN               NaN               NaN  ...
# 4                  NaN               NaN               NaN  ...
# ...                ...               ...               ...  ...
# 81706            Hindi      Dhiraj Kumar               NaN  ...
# 81707            Hindi     Chakri Toleti    Richard Harris  ...
# 81708          English       Dallas King               NaN  ...
# 81709  German, English       Detlev Buck               NaN  ...
# 81710           German     Til Schweiger               NaN  ...
#
#       country_202110 language_202110 isAdult  director_1_202110  \
# 0                 \N              \N       0      James Mangold
# 1                 \N              \N       0    Hiroshi Inagaki
# 2                 \N              \N       0          Raúl Ruiz
# 3                 \N              \N       0          Les Blank
# 4                 \N              \N       0  Frederick Wiseman
# ...              ...             ...     ...                ...
# 81706             \N              \N       0       Dhiraj Kumar
# 81707             \N              \N       0       Jasmine Kaur
# 81708             \N              \N       0        Dallas King
# 81709             \N              \N       0        Detlev Buck
# 81710             \N              \N       0      Til Schweiger
#
#        director_2_202110  writer_1_202110       writer_2_202110  \
# 0                    NaN    Steven Rogers         James Mangold
# 1                    NaN    Mansaku Itami     Shunsaku Iwashita
# 2      Valeria Sarmiento        Raúl Ruiz  Omar Saavedra Santis
# 3            Skip Gerson              NaN                   NaN
# 4            Tinto Brass              NaN                   NaN
# ...                  ...              ...                   ...
# 81706                NaN   Manish Kishore                   NaN
# 81707      Chakri Toleti     Sara Bodinar        Dheeraj Rattan
# 81708                NaN      Dallas King           Ehren Parks
# 81709                NaN   Andrea Willson                   NaN
# 81710                NaN  Claudia Boderke            Lo Malinke
#
#                                            actors_202110 avg_vote_202110  \
# 0      Meg Ryan,Hugh Jackman,Liev Schreiber,Breckin M...             6.4
# 1      Tsumasaburô Bandô,Keiko Sonoi,Yasushi Nagata,K...             7.3
# 2      Rubén Sotoconil,Claudia Paz,Luis Alarcón,Shend...             6.3
# 3                                       Wendell Anderson             7.0
# 4       Catherine Rouvel,Brooke Hayward,Branko Milicevic             5.7
# ...                                                  ...             ...
# 81706  Kranti Prakash Jha,Manoj Joshi,Aishwarya Devan...             5.4
# 81707  Lara Dutta,Sonakshi Sinha,Diljit Dosanjh,Karan...             1.6
# 81708  Thai Edwards,Ramon Antonio,Michael Dionne,Chri...             5.3
# 81709  Johanna Wokalek,Emily Cox,Marie Burchard,Maite...             5.0
# 81710  Til Schweiger,Samuel Finzi,Milan Peschel,Lilli...             3.6
#
#       votes_202110
# 0            81560
# 1              107
# 2              153
# 3              161
# 4              357
# ...            ...
# 81706          325
# 81707          834
# 81708         1101
# 81709          189
# 81710         1509
#
# [81711 rows x 32 columns]

# %%
imdb_combined_data = imdb_combined_data[['imdb_title_id','title_202001','title_202110','original_title_202110',
                   'year_202110','genre_202110','duration_202110',
                   'country_202001','language_202001','isAdult','director_1_202110','director_2_202110',
                   'writer_1_202110','writer_2_202110','actors_202110','avg_vote_202001','avg_vote_202110',
                   'votes_202001','votes_202110','budget','worlwide_gross_income']]

# %%
imdb_combined_data.rename({'original_title_202110':'original_title','year_202110':'release_year',
                          'genre_202110':"genre","country_202001":"country",'language_202001':'language',
                          'director_1_202110':'director_1','director_2_202110':'director_2',
                          'writer_1_202110':'writer_1','writer_2_202110':"writer_2",'actors_202110':"actors"},
                          axis=1,inplace=True)
# Out:
# C:\Users\kjkoo\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
imdb_combined_data = imdb_combined_data[~imdb_combined_data['genre'].str.contains('Short')].reset_index()

# %%
imdb_combined_data = imdb_combined_data[imdb_combined_data['duration_202110'] != "\\N"].reset_index()

# %%
# save combined version of data

imdb_combined_data.to_csv("imdb_combined_data.csv",index=False)

# %%
imdb_combined_data.drop(['level_0','index'],axis=1,inplace=True)

# %%
imdb_combined_data = pd.read_csv("Fin_dataset/imdb_combined_data.csv")

# %%
imdb_combined_data.columns
# Out:
# Index(['imdb_title_id', 'title_202001', 'title_202110', 'original_title',
#        'release_year', 'genre', 'duration_202110', 'country', 'language',
#        'isAdult', 'director_1', 'director_2', 'writer_1', 'writer_2', 'actors',
#        'avg_vote_202001', 'avg_vote_202110', 'votes_202001', 'votes_202110',
#        'budget', 'worlwide_gross_income'],
#       dtype='object')

# %%
imdb_combined_data = pd.merge(imdb_combined_data, sleceted_crew_name, how='left')
imdb_combined_data
# Out:
#       imdb_title_id               title_202001  \
# 0         tt0035423             Kate & Leopold
# 1         tt0036177                        NaN
# 2         tt0062336                        NaN
# 3         tt0069049   L'altra faccia del vento
# 4         tt0110476         Master i Margarita
# ...             ...                        ...
# 70262     tt7274806  Kaashi in Search of Ganga
# 70263     tt7275232        Welcome to New York
# 70264     tt7275352                      Demon
# 70265     tt7275816                       Wuff
# 70266     tt7275822         Klassentreffen 1.0
#
#                                     title_202110  \
# 0                                 Kate & Leopold
# 1                             Muhomatsu no issho
# 2      El Tango del Viudo y Su Espejo Deformante
# 3                     The Other Side of the Wind
# 4                             Master i Margarita
# ...                                          ...
# 70262                  Kaashi in Search of Ganga
# 70263                        Welcome to New York
# 70264                                      Demon
# 70265                                       Wuff
# 70266                         Klassentreffen 1.0
#
#                                   original_title  release_year  \
# 0                                 Kate & Leopold          2001
# 1                             Muhomatsu no issho          2008
# 2      El Tango del Viudo y Su Espejo Deformante          2020
# 3                     The Other Side of the Wind          2018
# 4                             Master i Margarita          2006
# ...                                          ...           ...
# 70262                  Kaashi in Search of Ganga          2018
# 70263                        Welcome to New York          2018
# 70264                                      Demon          2017
# 70265                                       Wuff          2018
# 70266                         Klassentreffen 1.0          2018
#
#                         genre  duration_202110            country  \
# 0      Comedy,Fantasy,Romance              118                USA
# 1            Action,Adventure              100                NaN
# 2                       Drama               70                NaN
# 3                       Drama              122  France, Iran, USA
# 4               Drama,Fantasy              125             Russia
# ...                       ...              ...                ...
# 70262                Thriller              125              India
# 70263            Comedy,Drama              118              India
# 70264                  Horror               70                USA
# 70265    Comedy,Drama,Romance              114            Germany
# 70266            Comedy,Drama              127            Germany
#
#               language  isAdult  ... directors_2    director_2_name  \
# 0      English, French        0  ...         NaN                NaN
# 1                  NaN        0  ...         NaN                NaN
# 2                  NaN        0  ...   nm0765384  Valeria Sarmiento
# 3      English, German        0  ...         NaN                NaN
# 4              Russian        0  ...         NaN                NaN
# ...                ...      ...  ...         ...                ...
# 70262            Hindi        0  ...         NaN                NaN
# 70263            Hindi        0  ...   nm3442103      Chakri Toleti
# 70264          English        0  ...         NaN                NaN
# 70265  German, English        0  ...         NaN                NaN
# 70266           German        0  ...         NaN                NaN
#
#           star_1        star_1_name     star_2             star_2_name  \
# 0      nm0000212           Meg Ryan  nm0413168            Hugh Jackman
# 1      nm0051765  Tsumasaburô Bandô  nm1671791             Keiko Sonoi
# 2      nm0815612    Rubén Sotoconil  nm1860495             Claudia Paz
# 3      nm0001379        John Huston  nm0462648               Oja Kodar
# 4      nm0707618       Viktor Rakov  nm0895034  Anastasiya Vertinskaya
# ...          ...                ...        ...                     ...
# 70262  nm7743919    Prince Adhikari  nm5240399         Aishwarya Devan
# 70263  nm3848064     Sonakshi Sinha  nm4362492          Diljit Dosanjh
# 70264  nm3813060      Ramon Antonio  nm1992311          Michael Dionne
# 70265  nm2686957          Emily Cox  nm0937557         Johanna Wokalek
# 70266  nm0001709      Til Schweiger  nm0278373            Samuel Finzi
#
#           star_3         star_3_name     star_4      star_4_name
# 0      nm0000630      Liev Schreiber  nm0005227    Breckin Meyer
# 1      nm0619218      Yasushi Nagata  nm1796246   Kamon Kawamura
# 2      nm0016013        Luis Alarcón  nm0739834     Shenda Román
# 3      nm0000953   Peter Bogdanovich  nm0001782  Susan Strasberg
# 4      nm0122168    Nikolay Burlyaev  nm0880761  Mikhail Ulyanov
# ...          ...                 ...        ...              ...
# 70262  nm6455555  Kranti Prakash Jha  nm1259084      Manoj Joshi
# 70263  nm0424103         Karan Johar  nm1069034       Lara Dutta
# 70264  nm4060376        Thai Edwards  nm9215150      Chris Kelly
# 70265  nm3281242      Marie Burchard  nm1556484      Maite Kelly
# 70266  nm0675919       Milan Peschel  nm2913100  Lilli Schweiger
#
# [70267 rows x 34 columns]

# %% [markdown]
# ## EXTRA) Crew name manipulation
#
# - I found that I have to add the key of directors, actors to combine it with another sources, and I did it after finshing combined data

# %%
# add crew name

crews_202110 = pd.read_csv('IMDB_movies_20211015/crew.tsv', header=0, sep='\t', quotechar='"', error_bad_lines=False, encoding='UTF-8')
crews_202110
# Out:
#             tconst            directors                        writers
# 0        tt0000001            nm0005690                             \N
# 1        tt0000002            nm0721526                             \N
# 2        tt0000003            nm0721526                             \N
# 3        tt0000004            nm0721526                             \N
# 4        tt0000005            nm0005690                             \N
# ...            ...                  ...                            ...
# 8360206  tt9916848  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8360207  tt9916850  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8360208  tt9916852  nm5519375,nm5519454  nm6182221,nm1628284,nm2921377
# 8360209  tt9916856           nm10538645                      nm6951431
# 8360210  tt9916880            nm0996406            nm1482639,nm2586970
#
# [8360211 rows x 3 columns]

# %%
# make a name of actor

actor_202110 = pd.read_csv('IMDB_movies_20211015/cast.tsv', header=0, sep='\t', quotechar='"', error_bad_lines=False, encoding='UTF-8')
actor_202110
# Out:
#              tconst  ordering      nconst         category  \
# 0         tt0000001         1   nm1588970             self
# 1         tt0000001         2   nm0005690         director
# 2         tt0000001         3   nm0374658  cinematographer
# 3         tt0000002         1   nm0721526         director
# 4         tt0000002         2   nm1335271         composer
# ...             ...       ...         ...              ...
# 47274790  tt9916880         4  nm10535738          actress
# 47274791  tt9916880         5   nm0996406         director
# 47274792  tt9916880         6   nm1482639           writer
# 47274793  tt9916880         7   nm2586970           writer
# 47274794  tt9916880         8   nm1594058         producer
#
#                               job        characters
# 0                              \N          ["Self"]
# 1                              \N                \N
# 2         director of photography                \N
# 3                              \N                \N
# 4                              \N                \N
# ...                           ...               ...
# 47274790                       \N  ["Horrid Henry"]
# 47274791       principal director                \N
# 47274792                       \N                \N
# 47274793                    books                \N
# 47274794                 producer                \N
#
# [47274795 rows x 6 columns]

# %%
actor_202110['category'].unique()
# Out:
# array(['self', 'director', 'cinematographer', 'composer', 'producer',
#        'editor', 'actor', 'actress', 'writer', 'production_designer',
#        'archive_footage', 'archive_sound'], dtype=object)

# %%
actor_202110 = actor_202110[actor_202110['category'].isin(['actor','actress'])]
actor_202110.head()
# Out:
#        tconst  ordering     nconst category job        characters
# 11  tt0000005         1  nm0443482    actor  \N    ["Blacksmith"]
# 12  tt0000005         2  nm0653042    actor  \N     ["Assistant"]
# 16  tt0000007         1  nm0179163    actor  \N                \N
# 17  tt0000007         2  nm0183947    actor  \N                \N
# 21  tt0000008         1  nm0653028    actor  \N  ["Sneezing Man"]

# %%
# make actor list on one cell

actor_202110 = actor_202110.groupby(['tconst'])['nconst'].apply(lambda x: ','.join(x)).reset_index()
actor_202110
# Out:
#             tconst                                      nconst
# 0        tt0000005                         nm0443482,nm0653042
# 1        tt0000007                         nm0179163,nm0183947
# 2        tt0000008                                   nm0653028
# 3        tt0000009               nm0063086,nm0183823,nm1309758
# 4        tt0000011                                   nm3692297
# ...            ...                                         ...
# 4685219  tt9916848     nm5519557,nm8825009,nm5262613,nm8690065
# 4685220  tt9916850     nm5519557,nm8825009,nm5262613,nm8690065
# 4685221  tt9916852     nm5519557,nm8825009,nm5262613,nm8690065
# 4685222  tt9916856  nm3394271,nm10538650,nm10538646,nm10538647
# 4685223  tt9916880    nm1483166,nm0254176,nm0286175,nm10535738
#
# [4685224 rows x 2 columns]

# %%
# crew + actor

all_crew = pd.merge(crews_202110, actor_202110)
all_crew = all_crew[['tconst','directors','nconst']]
all_crew
# Out:
#             tconst            directors  \
# 0        tt0000005            nm0005690
# 1        tt0000007  nm0374658,nm0005690
# 2        tt0000008            nm0005690
# 3        tt0000009            nm0085156
# 4        tt0000011            nm0804434
# ...            ...                  ...
# 4685129  tt9916848  nm5519454,nm5519375
# 4685130  tt9916850  nm5519454,nm5519375
# 4685131  tt9916852  nm5519375,nm5519454
# 4685132  tt9916856           nm10538645
# 4685133  tt9916880            nm0996406
#
#                                              nconst
# 0                               nm0443482,nm0653042
# 1                               nm0179163,nm0183947
# 2                                         nm0653028
# 3                     nm0063086,nm0183823,nm1309758
# 4                                         nm3692297
# ...                                             ...
# 4685129     nm5519557,nm8825009,nm5262613,nm8690065
# 4685130     nm5519557,nm8825009,nm5262613,nm8690065
# 4685131     nm5519557,nm8825009,nm5262613,nm8690065
# 4685132  nm3394271,nm10538650,nm10538646,nm10538647
# 4685133    nm1483166,nm0254176,nm0286175,nm10535738
#
# [4685134 rows x 3 columns]

# %%
# get at most 2 dircetors, 4 stars -> split each columns 

all_crew
# Out:
#             tconst            directors  \
# 0        tt0000005            nm0005690
# 1        tt0000007  nm0374658,nm0005690
# 2        tt0000008            nm0005690
# 3        tt0000009            nm0085156
# 4        tt0000011            nm0804434
# ...            ...                  ...
# 4685129  tt9916848  nm5519454,nm5519375
# 4685130  tt9916850  nm5519454,nm5519375
# 4685131  tt9916852  nm5519375,nm5519454
# 4685132  tt9916856           nm10538645
# 4685133  tt9916880            nm0996406
#
#                                              nconst
# 0                               nm0443482,nm0653042
# 1                               nm0179163,nm0183947
# 2                                         nm0653028
# 3                     nm0063086,nm0183823,nm1309758
# 4                                         nm3692297
# ...                                             ...
# 4685129     nm5519557,nm8825009,nm5262613,nm8690065
# 4685130     nm5519557,nm8825009,nm5262613,nm8690065
# 4685131     nm5519557,nm8825009,nm5262613,nm8690065
# 4685132  nm3394271,nm10538650,nm10538646,nm10538647
# 4685133    nm1483166,nm0254176,nm0286175,nm10535738
#
# [4685134 rows x 3 columns]

# %%
all_crew['directors_1'] = all_crew['directors'].str.split(',').str[0]
all_crew['directors_2'] = all_crew['directors'].str.split(',').str[1]
all_crew['star_1'] = all_crew['nconst'].str.split(',').str[0]
all_crew['star_2'] = all_crew['nconst'].str.split(',').str[1]
all_crew['star_3'] = all_crew['nconst'].str.split(',').str[2]
all_crew['star_4'] = all_crew['nconst'].str.split(',').str[3]

# %%
all_crew
# Out:
#             tconst            directors  \
# 0        tt0000005            nm0005690
# 1        tt0000007  nm0374658,nm0005690
# 2        tt0000008            nm0005690
# 3        tt0000009            nm0085156
# 4        tt0000011            nm0804434
# ...            ...                  ...
# 4685129  tt9916848  nm5519454,nm5519375
# 4685130  tt9916850  nm5519454,nm5519375
# 4685131  tt9916852  nm5519375,nm5519454
# 4685132  tt9916856           nm10538645
# 4685133  tt9916880            nm0996406
#
#                                              nconst directors_1 directors_2  \
# 0                               nm0443482,nm0653042   nm0005690         NaN
# 1                               nm0179163,nm0183947   nm0374658   nm0005690
# 2                                         nm0653028   nm0005690         NaN
# 3                     nm0063086,nm0183823,nm1309758   nm0085156         NaN
# 4                                         nm3692297   nm0804434         NaN
# ...                                             ...         ...         ...
# 4685129     nm5519557,nm8825009,nm5262613,nm8690065   nm5519454   nm5519375
# 4685130     nm5519557,nm8825009,nm5262613,nm8690065   nm5519454   nm5519375
# 4685131     nm5519557,nm8825009,nm5262613,nm8690065   nm5519375   nm5519454
# 4685132  nm3394271,nm10538650,nm10538646,nm10538647  nm10538645         NaN
# 4685133    nm1483166,nm0254176,nm0286175,nm10535738   nm0996406         NaN
#
#             star_1      star_2      star_3      star_4
# 0        nm0443482   nm0653042         NaN         NaN
# 1        nm0179163   nm0183947         NaN         NaN
# 2        nm0653028         NaN         NaN         NaN
# 3        nm0063086   nm0183823   nm1309758         NaN
# 4        nm3692297         NaN         NaN         NaN
# ...            ...         ...         ...         ...
# 4685129  nm5519557   nm8825009   nm5262613   nm8690065
# 4685130  nm5519557   nm8825009   nm5262613   nm8690065
# 4685131  nm5519557   nm8825009   nm5262613   nm8690065
# 4685132  nm3394271  nm10538650  nm10538646  nm10538647
# 4685133  nm1483166   nm0254176   nm0286175  nm10535738
#
# [4685134 rows x 9 columns]

# %%
# match each cell with the crew names dataset

crew_names_202110 = crew_names_202110[['nconst','primaryName']]

# %%
# Since I have a memory error, I have to combine the data with my original dataset

imdb_combined_data = pd.read_csv("Fin_dataset/imdb_combined_data.csv")

selceted_crew = pd.merge(imdb_combined_data,all_crew, left_on='imdb_title_id', right_on='tconst', how='left')
selceted_crew = selceted_crew[['imdb_title_id','directors','nconst','directors_1','directors_2','star_1','star_2','star_3',
              'star_4']]
selceted_crew
# Out:
#       imdb_title_id                        directors  \
# 0         tt0035423                        nm0003506
# 1         tt0036177                        nm0408348
# 2         tt0062336              nm0749914,nm0765384
# 3         tt0069049                        nm0000080
# 4         tt0110476                        nm0438671
# ...             ...                              ...
# 69806     tt7274806                        nm9180204
# 69807     tt7275232  nm10468914,nm3442103,nm10468913
# 69808     tt7275352                        nm2474410
# 69809     tt7275816                        nm0118345
# 69810     tt7275822                        nm0001709
#
#                                         nconst directors_1 directors_2  \
# 0      nm0000212,nm0413168,nm0000630,nm0005227   nm0003506         NaN
# 1      nm0051765,nm1671791,nm0619218,nm1796246   nm0408348         NaN
# 2      nm0815612,nm1860495,nm0016013,nm0739834   nm0749914   nm0765384
# 3      nm0001379,nm0462648,nm0000953,nm0001782   nm0000080         NaN
# 4      nm0707618,nm0895034,nm0122168,nm0880761   nm0438671         NaN
# ...                                        ...         ...         ...
# 69806  nm7743919,nm5240399,nm6455555,nm1259084   nm9180204         NaN
# 69807  nm3848064,nm4362492,nm0424103,nm1069034  nm10468914   nm3442103
# 69808  nm3813060,nm1992311,nm4060376,nm9215150   nm2474410         NaN
# 69809  nm2686957,nm0937557,nm3281242,nm1556484   nm0118345         NaN
# 69810  nm0001709,nm0278373,nm0675919,nm2913100   nm0001709         NaN
#
#           star_1     star_2     star_3     star_4
# 0      nm0000212  nm0413168  nm0000630  nm0005227
# 1      nm0051765  nm1671791  nm0619218  nm1796246
# 2      nm0815612  nm1860495  nm0016013  nm0739834
# 3      nm0001379  nm0462648  nm0000953  nm0001782
# 4      nm0707618  nm0895034  nm0122168  nm0880761
# ...          ...        ...        ...        ...
# 69806  nm7743919  nm5240399  nm6455555  nm1259084
# 69807  nm3848064  nm4362492  nm0424103  nm1069034
# 69808  nm3813060  nm1992311  nm4060376  nm9215150
# 69809  nm2686957  nm0937557  nm3281242  nm1556484
# 69810  nm0001709  nm0278373  nm0675919  nm2913100
#
# [69811 rows x 9 columns]

# %%
name_1 = pd.merge(selceted_crew, crew_names_202110, how='left', left_on='directors_1', right_on='nconst')
name_1.rename(columns = {"primaryName":"director_1_name"},inplace=True)
name_2 = pd.merge(name_1, crew_names_202110,how='left', left_on='directors_2', right_on='nconst')
name_2.rename(columns = {"primaryName":"director_2_name"},inplace=True)
name_3 = pd.merge(name_2, crew_names_202110,how='left', left_on='star_1', right_on='nconst')
name_3.rename(columns = {"primaryName":"star_1_name"},inplace=True)
name_4 = pd.merge(name_3, crew_names_202110,how='left', left_on='star_2', right_on='nconst')
name_4.rename(columns = {"primaryName":"star_2_name"},inplace=True)
name_5 = pd.merge(name_4, crew_names_202110,how='left', left_on='star_3', right_on='nconst')
name_5.rename(columns = {"primaryName":"star_3_name"},inplace=True)
sleceted_crew_name = pd.merge(name_5, crew_names_202110,how='left', left_on='star_4', right_on='nconst')
sleceted_crew_name.rename(columns = {"primaryName":"star_4_name"},inplace=True)
sleceted_crew_name
# Out:
#       imdb_title_id                        directors  \
# 0         tt0035423                        nm0003506
# 1         tt0036177                        nm0408348
# 2         tt0062336              nm0749914,nm0765384
# 3         tt0069049                        nm0000080
# 4         tt0110476                        nm0438671
# ...             ...                              ...
# 69806     tt7274806                        nm9180204
# 69807     tt7275232  nm10468914,nm3442103,nm10468913
# 69808     tt7275352                        nm2474410
# 69809     tt7275816                        nm0118345
# 69810     tt7275822                        nm0001709
#
#                                       nconst_x directors_1 directors_2  \
# 0      nm0000212,nm0413168,nm0000630,nm0005227   nm0003506         NaN
# 1      nm0051765,nm1671791,nm0619218,nm1796246   nm0408348         NaN
# 2      nm0815612,nm1860495,nm0016013,nm0739834   nm0749914   nm0765384
# 3      nm0001379,nm0462648,nm0000953,nm0001782   nm0000080         NaN
# 4      nm0707618,nm0895034,nm0122168,nm0880761   nm0438671         NaN
# ...                                        ...         ...         ...
# 69806  nm7743919,nm5240399,nm6455555,nm1259084   nm9180204         NaN
# 69807  nm3848064,nm4362492,nm0424103,nm1069034  nm10468914   nm3442103
# 69808  nm3813060,nm1992311,nm4060376,nm9215150   nm2474410         NaN
# 69809  nm2686957,nm0937557,nm3281242,nm1556484   nm0118345         NaN
# 69810  nm0001709,nm0278373,nm0675919,nm2913100   nm0001709         NaN
#
#           star_1     star_2     star_3     star_4    nconst_y  ...   nconst_x  \
# 0      nm0000212  nm0413168  nm0000630  nm0005227   nm0003506  ...        NaN
# 1      nm0051765  nm1671791  nm0619218  nm1796246   nm0408348  ...        NaN
# 2      nm0815612  nm1860495  nm0016013  nm0739834   nm0749914  ...  nm0765384
# 3      nm0001379  nm0462648  nm0000953  nm0001782   nm0000080  ...        NaN
# 4      nm0707618  nm0895034  nm0122168  nm0880761   nm0438671  ...        NaN
# ...          ...        ...        ...        ...         ...  ...        ...
# 69806  nm7743919  nm5240399  nm6455555  nm1259084   nm9180204  ...        NaN
# 69807  nm3848064  nm4362492  nm0424103  nm1069034  nm10468914  ...  nm3442103
# 69808  nm3813060  nm1992311  nm4060376  nm9215150   nm2474410  ...        NaN
# 69809  nm2686957  nm0937557  nm3281242  nm1556484   nm0118345  ...        NaN
# 69810  nm0001709  nm0278373  nm0675919  nm2913100   nm0001709  ...        NaN
#
#          director_2_name   nconst_y        star_1_name   nconst_x  \
# 0                    NaN  nm0000212           Meg Ryan  nm0413168
# 1                    NaN  nm0051765  Tsumasaburô Bandô  nm1671791
# 2      Valeria Sarmiento  nm0815612    Rubén Sotoconil  nm1860495
# 3                    NaN  nm0001379        John Huston  nm0462648
# 4                    NaN  nm0707618       Viktor Rakov  nm0895034
# ...                  ...        ...                ...        ...
# 69806                NaN  nm7743919    Prince Adhikari  nm5240399
# 69807      Chakri Toleti  nm3848064     Sonakshi Sinha  nm4362492
# 69808                NaN  nm3813060      Ramon Antonio  nm1992311
# 69809                NaN  nm2686957          Emily Cox  nm0937557
# 69810                NaN  nm0001709      Til Schweiger  nm0278373
#
#                   star_2_name   nconst_y         star_3_name     nconst  \
# 0                Hugh Jackman  nm0000630      Liev Schreiber  nm0005227
# 1                 Keiko Sonoi  nm0619218      Yasushi Nagata  nm1796246
# 2                 Claudia Paz  nm0016013        Luis Alarcón  nm0739834
# 3                   Oja Kodar  nm0000953   Peter Bogdanovich  nm0001782
# 4      Anastasiya Vertinskaya  nm0122168    Nikolay Burlyaev  nm0880761
# ...                       ...        ...                 ...        ...
# 69806         Aishwarya Devan  nm6455555  Kranti Prakash Jha  nm1259084
# 69807          Diljit Dosanjh  nm0424103         Karan Johar  nm1069034
# 69808          Michael Dionne  nm4060376        Thai Edwards  nm9215150
# 69809         Johanna Wokalek  nm3281242      Marie Burchard  nm1556484
# 69810            Samuel Finzi  nm0675919       Milan Peschel  nm2913100
#
#            star_4_name
# 0        Breckin Meyer
# 1       Kamon Kawamura
# 2         Shenda Román
# 3      Susan Strasberg
# 4      Mikhail Ulyanov
# ...                ...
# 69806      Manoj Joshi
# 69807       Lara Dutta
# 69808      Chris Kelly
# 69809      Maite Kelly
# 69810  Lilli Schweiger
#
# [69811 rows x 21 columns]

# %%
sleceted_crew_name = sleceted_crew_name[['imdb_title_id','directors',"directors_1",'director_1_name','directors_2','director_2_name',
                   'star_1','star_1_name','star_2','star_2_name','star_3','star_3_name','star_4','star_4_name']]
sleceted_crew_name
# Out:
#       imdb_title_id                        directors directors_1  \
# 0         tt0035423                        nm0003506   nm0003506
# 1         tt0036177                        nm0408348   nm0408348
# 2         tt0062336              nm0749914,nm0765384   nm0749914
# 3         tt0069049                        nm0000080   nm0000080
# 4         tt0110476                        nm0438671   nm0438671
# ...             ...                              ...         ...
# 69806     tt7274806                        nm9180204   nm9180204
# 69807     tt7275232  nm10468914,nm3442103,nm10468913  nm10468914
# 69808     tt7275352                        nm2474410   nm2474410
# 69809     tt7275816                        nm0118345   nm0118345
# 69810     tt7275822                        nm0001709   nm0001709
#
#        director_1_name directors_2    director_2_name     star_1  \
# 0        James Mangold         NaN                NaN  nm0000212
# 1      Hiroshi Inagaki         NaN                NaN  nm0051765
# 2            Raúl Ruiz   nm0765384  Valeria Sarmiento  nm0815612
# 3         Orson Welles         NaN                NaN  nm0001379
# 4           Yuriy Kara         NaN                NaN  nm0707618
# ...                ...         ...                ...        ...
# 69806     Dhiraj Kumar         NaN                NaN  nm7743919
# 69807     Jasmine Kaur   nm3442103      Chakri Toleti  nm3848064
# 69808      Dallas King         NaN                NaN  nm3813060
# 69809      Detlev Buck         NaN                NaN  nm2686957
# 69810    Til Schweiger         NaN                NaN  nm0001709
#
#              star_1_name     star_2             star_2_name     star_3  \
# 0               Meg Ryan  nm0413168            Hugh Jackman  nm0000630
# 1      Tsumasaburô Bandô  nm1671791             Keiko Sonoi  nm0619218
# 2        Rubén Sotoconil  nm1860495             Claudia Paz  nm0016013
# 3            John Huston  nm0462648               Oja Kodar  nm0000953
# 4           Viktor Rakov  nm0895034  Anastasiya Vertinskaya  nm0122168
# ...                  ...        ...                     ...        ...
# 69806    Prince Adhikari  nm5240399         Aishwarya Devan  nm6455555
# 69807     Sonakshi Sinha  nm4362492          Diljit Dosanjh  nm0424103
# 69808      Ramon Antonio  nm1992311          Michael Dionne  nm4060376
# 69809          Emily Cox  nm0937557         Johanna Wokalek  nm3281242
# 69810      Til Schweiger  nm0278373            Samuel Finzi  nm0675919
#
#               star_3_name     star_4      star_4_name
# 0          Liev Schreiber  nm0005227    Breckin Meyer
# 1          Yasushi Nagata  nm1796246   Kamon Kawamura
# 2            Luis Alarcón  nm0739834     Shenda Román
# 3       Peter Bogdanovich  nm0001782  Susan Strasberg
# 4        Nikolay Burlyaev  nm0880761  Mikhail Ulyanov
# ...                   ...        ...              ...
# 69806  Kranti Prakash Jha  nm1259084      Manoj Joshi
# 69807         Karan Johar  nm1069034       Lara Dutta
# 69808        Thai Edwards  nm9215150      Chris Kelly
# 69809      Marie Burchard  nm1556484      Maite Kelly
# 69810       Milan Peschel  nm2913100  Lilli Schweiger
#
# [69811 rows x 14 columns]

# %%
# Final dataset for 202110, save

imdb_data_202110 = pd.merge(imdb_dat_202110, crew_merge, how='left')
imdb_data_202110 = pd.merge(imdb_data_202110,actor_202110_name, how='outer',left_on='imdb_title_id', right_on = 'tconst')
imdb_data_202110.to_csv('imdb_data_202110.csv',index=False, encoding='UTF-8')

# %%
imdb_data_202110.columns
# Out:
# Index(['imdb_title_id', 'averageRating', 'numVotes', 'ordering', 'title',
#        'region', 'language', 'types', 'attributes', 'isOriginalTitle',
#        'primaryTitle', 'originalTitle', 'isAdult', 'startYear',
#        'runtimeMinutes', 'genres', 'director_1', 'director_2', 'writer_1',
#        'writer_2', 'tconst', 'primaryName'],
#       dtype='object')

# %%
# save final version of data

imdb_combined_data.columns
imdb_combined_data_fin = imdb_combined_data[['imdb_title_id','title_202001','title_202110','original_title','release_year','genre',
                    'duration_202110','country',
                   'language','isAdult','director_1','director_1_name','director_2','director_2_name',
                   'star_1','star_1_name','star_2','star_2_name','star_3','star_3_name','star_4','star_4_name',
                   'actors','avg_vote_202001','avg_vote_202110','votes_202001','votes_202110','budget']]

imdb_combined_data.to_csv("imdb_combined_data_fin.csv", index=False, encoding='utf-8')

# %% [markdown]
# # 2. Building OTT Movie data

# %% [markdown]
# #### Each data are downloaded from kaggle
#
# - Netflix: https://www.kaggle.com/shivamb/netflix-shows
# - Amazon Prime: https://www.kaggle.com/shivamb/amazon-prime-movies-and-tv-shows
# - Disney: https://www.kaggle.com/shivamb/disney-movies-and-tv-shows
# - With these dataset, I combined it together and add the columns if that data is availble on the OTT(eg: amazon_prime 0 refert not available on amazon)
#
# ** Data is scrapped on the mid of 2021

# %%
df = pd.read_csv("ott_moive.csv")

# %%
df
# Out:
#                                           title  \
# 0                           The Grand Seduction
# 1                          Take Care Good Night
# 2                          Secrets of Deception
# 3                            Pink: Staying True
# 4                                 Monster Maker
# ...                                         ...
# 14921  Lady and the Tramp II: Scamp's Adventure
# 14922                  The Cat from Outer Space
# 14923                 The Great Mouse Detective
# 14924                    The Sword in the Stone
# 14925                           Those Calloways
#
#                                        director  \
# 0                                  Don McKellar
# 1                                  Girish Joshi
# 2                                   Josh Webber
# 3                                Sonia Anderson
# 4                                  Giles Foster
# ...                                         ...
# 14921                            Darrell Rooney
# 14922                              Norman Tokar
# 14923  John Musker, Ron Clements, Dave Michener
# 14924                       Wolfgang Reitherman
# 14925                              Norman Tokar
#
#                                                     cast  \
# 0         Brendan Gleeson, Taylor Kitsch, Gordon Pinsent
# 1       Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar
# 2      Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...
# 3      Interviews with: Pink, Adele, Beyonc챕, Britney...
# 4      Harry Dean Stanton, Kieran O'Brien, George Cos...
# ...                                                  ...
# 14921  Scott Wolf, Alyssa Milano, Chazz Palminteri, J...
# 14922  Ken Berry, Sandy Duncan, Harry Morgan, Roddy M...
# 14923  Vincent Price, Barrie Ingham, Val Bettin, Susa...
# 14924  Sebastian Cabot, Karl Swenson, Rickie Sorensen...
# 14925  Brian Keith, Vera Miles, Brandon de Wilde, Wal...
#
#                         country date_added release_year rating duration  \
# 0                        Canada  30-Mar-21         2014    NaN  113 min
# 1                         India  30-Mar-21         2018    13+  110 min
# 2                 United States  30-Mar-21         2017    NaN   74 min
# 3                 United States  30-Mar-21         2014    NaN   69 min
# 4                United Kingdom  30-Mar-21         1989    NaN   45 min
# ...                         ...        ...          ...    ...      ...
# 14921  United States, Australia  01-Oct-19         2001      G   73 min
# 14922             United States  01-Oct-19         1978      G  104 min
# 14923             United States  01-Oct-19         1986      G   75 min
# 14924             United States  01-Oct-19         1963      G   80 min
# 14925             United States  01-Oct-19         1965     PG  132 min
#
#                                         listed_in  amazon_prime  netflix  \
# 0                                   Comedy, Drama             1        0
# 1                            Drama, International             1        0
# 2                         Action, Drama, Suspense             1        0
# 3                                     Documentary             1        0
# 4                                  Drama, Fantasy             1        0
# ...                                           ...           ...      ...
# 14921  Action-Adventure, Animation, Coming of Age             0        0
# 14922             Comedy, Family, Science Fiction             0        0
# 14923                  Animation, Family, Mystery             0        0
# 14924         Action-Adventure, Animation, Comedy             0        0
# 14925             Animals & Nature, Drama, Family             0        0
#
#        dsiney
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 14921       1
# 14922       1
# 14923       1
# 14924       1
# 14925       1
#
# [14926 rows x 12 columns]

# %%
df_avail = df.groupby(by='title',as_index=False)[['amazon_prime','netflix','dsiney']].sum()
df_avail['num_avail'] = df_avail['amazon_prime'] + df_avail['netflix'] + df_avail['dsiney']
df_avail = pd.merge(df, df_avail, how="right")
df_avail.head()
# Out:
#                            title                     director  \
# 0                     "Mixed Up"                 Nishi Chawla
# 1                         #Alive                       Cho Il
# 2  #AnneFrank - Parallel Stories  Sabina Fedeli, Anna Migotto
# 3              #FriendButMarried                Rako Prijanto
# 4            #FriendButMarried 2                Rako Prijanto
#
#                                                 cast      country date_added  \
# 0  UDAY KRISHNA, BETHANY RISHELL, LUCY BOND, SANJ...          NaN        NaN
# 1                           Yoo Ah-in, Park Shin-hye  South Korea  08-Sep-20
# 2                        Helen Mirren, Gengher Gatti        Italy  01-Jul-20
# 3  Adipati Dolken, Vanesha Prescilla, Rendi Jhon,...    Indonesia  21-May-20
# 4  Adipati Dolken, Mawar de Jongh, Sari Nila, Von...    Indonesia  28-Jun-20
#
#   release_year rating duration  \
# 0         2020    16+  106 min
# 1         2020  TV-MA   99 min
# 2         2019  TV-14   95 min
# 3         2018   TV-G  102 min
# 4         2020   TV-G  104 min
#
#                                         listed_in  amazon_prime  netflix  \
# 0                                  Drama, Romance             1        0
# 1  Horror Movies, International Movies, Thrillers             0        1
# 2             Documentaries, International Movies             0        1
# 3   Dramas, International Movies, Romantic Movies             0        1
# 4   Dramas, International Movies, Romantic Movies             0        1
#
#    dsiney  num_avail
# 0       0          1
# 1       0          1
# 2       0          1
# 3       0          1
# 4       0          1

# %%
# Save Final version of adata

df_avail.to_csv('ott_test.csv')

# %% [markdown]
# # 3. Building Driector, Stars dataset
#
# Since the directors, Stars are really important varations for measuring the sucess of Movie, we use this dataset as an proxy of power of directors and stars

# %% [markdown]
# ### Data source
#
# ##### 1) Directors
# - Most popular director from imdb poll : https://www.imdb.com/list/ls026411399/<br>
# (All points from my Top of the Pops Lists and only from films with more than 500 points)
# - Oscar winner director: https://www.imdb.com/list/ls076968037/
# - Inocme of director: https://www.the-numbers.com/box-office-star-records/worldwide/lifetime-specific-technical-role/director
#
# ##### 2) Actors
# - Oscar winner actor: https://www.imdb.com/list/ls000067997/
# - Most popular actor from imdb poll: https://www.imdb.com/list/ls022928819/<br>
# (All points from my Top of the Pops Lists and only from films with more than 500 points.)
#
# ##### 3) Actress
# - Oscar winner actress: https://www.imdb.com/list/ls000067814/
# - Most popular actress from imdb poll: https://www.imdb.com/list/ls022928836/<br>
# (All points from my Top of the Pops Lists and only from films with more than 500 points.)

# %%
## Building Directors dataset

income_driector = pd.read_csv('director_income.csv')
academy_director = pd.read_csv('acadmey_awards_best_director.csv')
popularity_director = pd.read_csv('popularity_director.csv')

# %%
academy_director['academny_winner'] = 1

# %%
academy_director = academy_director[['Const','Name','academny_winner']]
academy_director
# Out:
#         Const                   Name  academny_winner
# 0   nm0001008            Frank Capra                1
# 1   nm0000406              John Ford                1
# 2   nm0001008            Frank Capra                1
# 3   nm0564970            Leo McCarey                1
# 4   nm0001008            Frank Capra                1
# ..        ...                    ...              ...
# 83  nm0327944  Alejandro G. I��rritu                1
# 84  nm3227090        Damien Chazelle                1
# 85  nm0868219     Guillermo del Toro                1
# 86  nm0190859          Alfonso Cuar?                1
# 87  nm0094435           Bong Joon Ho                1
#
# [88 rows x 3 columns]

# %%
popularity_director = popularity_director[['Const','Description','Name']]

# %%
popularity_director
# Out:
#          Const    Description               Name
# 0    nm0634240  143174 points  Christopher Nolan
# 1    nm0000229  131784 points   Steven Spielberg
# 2    nm0000233  108315 points  Quentin Tarantino
# 3    nm0000217  103526 points    Martin Scorsese
# 4    nm0000399   83185 points      David Fincher
# ..         ...            ...                ...
# 664  nm0172772     504 points    Peter Collinson
# 665  nm0959774     504 points     Jonas �kerlund
# 666  nm0527109     504 points          Rod Lurie
# 667  nm0248942     502 points           Uli Edel
# 668  nm0000425     500 points    Peter Greenaway
#
# [669 rows x 3 columns]

# %%
director_dataset_1 = pd.merge(popularity_director,academy_director,on = 'Const',how = 'outer')

# %%
director_dataset_1['academny_winner'].fillna(0,inplace=True)
director_dataset_1['Name_x'].fillna(director_dataset_1['Name_y'],inplace=True)
director_dataset_1 = director_dataset_1[['Const','Description','Name_x','academny_winner']]
director_dataset_1
# Out:
#          Const    Description             Name_x  academny_winner
# 0    nm0634240  143174 points  Christopher Nolan              0.0
# 1    nm0000229  131784 points   Steven Spielberg              1.0
# 2    nm0000229  131784 points   Steven Spielberg              1.0
# 3    nm0000233  108315 points  Quentin Tarantino              0.0
# 4    nm0000217  103526 points    Martin Scorsese              1.0
# ..         ...            ...                ...              ...
# 694  nm0730385            NaN     Jerome Robbins              1.0
# 695  nm0724798            NaN    Tony Richardson              1.0
# 696  nm0002080            NaN          Bob Fosse              1.0
# 697  nm0000886            NaN      Warren Beatty              1.0
# 698  nm0001053            NaN         Ethan Coen              1.0
#
# [699 rows x 4 columns]

# %%
director_dataset_1.columns = ["const", 'popularity_point', "name", 'academy_winner']
director_dataset_1
# Out:
#          const popularity_point               name  academy_winner
# 0    nm0634240    143174 points  Christopher Nolan             0.0
# 1    nm0000229    131784 points   Steven Spielberg             1.0
# 2    nm0000229    131784 points   Steven Spielberg             1.0
# 3    nm0000233    108315 points  Quentin Tarantino             0.0
# 4    nm0000217    103526 points    Martin Scorsese             1.0
# ..         ...              ...                ...             ...
# 694  nm0730385              NaN     Jerome Robbins             1.0
# 695  nm0724798              NaN    Tony Richardson             1.0
# 696  nm0002080              NaN          Bob Fosse             1.0
# 697  nm0000886              NaN      Warren Beatty             1.0
# 698  nm0001053              NaN         Ethan Coen             1.0
#
# [699 rows x 4 columns]

# %%
income_driector = income_driector[['Name','Worldwide','Movies','Average', 'Rank']]
income_driector
# Out:
#                   Name         Worldwide  Movies        Average  Rank
# 0     Steven Spielberg  $10,548,605,203       36  $293,016,811      1
# 1            Joe Russo   $6,839,063,507        8  $854,882,938      2
# 2        Anthony Russo   $6,839,063,507        7  $977,009,072      3
# 3        Peter Jackson   $6,535,061,813       14  $466,790,130      4
# 4          Michael Bay   $6,443,668,115       16  $402,729,257      5
# ...                ...               ...     ...            ...   ...
# 1995           Eva Jin          26212188       2       13106094  1996
# 1996   Catherine Owens          26170402       1       26170402  1997
# 1997     Afonso Poyart          26161035       2       13080518  1998
# 1998     Koichiro Miki          26115065       5        5223013  1999
# 1999      Andrew Hyatt          26113401       3        8704467  2000
#
# [2000 rows x 5 columns]

# %%
director_dataset = pd.merge(director_dataset_1,income_driector, left_on = 'name', right_on = 'Name', how="left")
director_dataset.fillna(0,inplace=True)

# %%
# get only number from popularity_point, Worldwide, Average
import re

def extract_num(w):
  w = w.strip()
  w = re.sub(r"[^0-9]+", "", w)
  w = w.strip()
  return w

# %%
director_dataset
# Out:
#          const popularity_point               name  academy_winner  \
# 0    nm0634240    143174 points  Christopher Nolan             0.0
# 1    nm0000229    131784 points   Steven Spielberg             1.0
# 2    nm0000229    131784 points   Steven Spielberg             1.0
# 3    nm0000233    108315 points  Quentin Tarantino             0.0
# 4    nm0000217    103526 points    Martin Scorsese             1.0
# ..         ...              ...                ...             ...
# 694  nm0730385                0     Jerome Robbins             1.0
# 695  nm0724798                0    Tony Richardson             1.0
# 696  nm0002080                0          Bob Fosse             1.0
# 697  nm0000886                0      Warren Beatty             1.0
# 698  nm0001053                0         Ethan Coen             1.0
#
#                   Name         Worldwide  Movies        Average    Rank
# 0    Christopher Nolan   $4,959,648,868     13.0  $381,511,451      8.0
# 1     Steven Spielberg  $10,548,605,203     36.0  $293,016,811      1.0
# 2     Steven Spielberg  $10,548,605,203     36.0  $293,016,811      1.0
# 3    Quentin Tarantino   $1,972,042,034     11.0  $179,276,549     63.0
# 4      Martin Scorsese   $2,153,734,709     30.0   $71,791,157     53.0
# ..                 ...               ...     ...            ...     ...
# 694                  0                 0     0.0              0     0.0
# 695    Tony Richardson          43726674     5.0        8745335  1560.0
# 696          Bob Fosse          93623112     4.0       23405778  1034.0
# 697      Warren Beatty         344613557     5.0       68922711   484.0
# 698         Ethan Coen     $537,119,703      7.0   $76,731,386    321.0
#
# [699 rows x 9 columns]

# %%
director_dataset['popularity_point'] = director_dataset['popularity_point'].astype('str').apply(extract_num).astype('int')
#director_dataset['Worldwide'] = director_dataset['Worldwide'].astype('str').apply(extract_num).astype('int')
director_dataset['Average'] = director_dataset['Average'].astype('str').apply(extract_num).astype('int')
director_dataset.drop('Worldwide',axis=1,inplace=True)
director_dataset.rename(columns={"Average":"Average_income"},inplace=True)
director_dataset = director_dataset[['const','name','Movies','Average_income','academy_winner',
                                     'popularity_point',]]
director_dataset.columns = ['const','name', 'num_movies','average_income','director_academy_winner',
                            'deriector_popularity_point']
director_dataset
# Out:
#          const  popularity_point               name  academy_winner  \
# 0    nm0634240            143174  Christopher Nolan             0.0
# 1    nm0000229            131784   Steven Spielberg             1.0
# 2    nm0000229            131784   Steven Spielberg             1.0
# 3    nm0000233            108315  Quentin Tarantino             0.0
# 4    nm0000217            103526    Martin Scorsese             1.0
# ..         ...               ...                ...             ...
# 694  nm0730385                 0     Jerome Robbins             1.0
# 695  nm0724798                 0    Tony Richardson             1.0
# 696  nm0002080                 0          Bob Fosse             1.0
# 697  nm0000886                 0      Warren Beatty             1.0
# 698  nm0001053                 0         Ethan Coen             1.0
#
#                   Name  Movies  Average_income    Rank
# 0    Christopher Nolan    13.0       381511451     8.0
# 1     Steven Spielberg    36.0       293016811     1.0
# 2     Steven Spielberg    36.0       293016811     1.0
# 3    Quentin Tarantino    11.0       179276549    63.0
# 4      Martin Scorsese    30.0        71791157    53.0
# ..                 ...     ...             ...     ...
# 694                  0     0.0               0     0.0
# 695    Tony Richardson     5.0         8745335  1560.0
# 696          Bob Fosse     4.0        23405778  1034.0
# 697      Warren Beatty     5.0        68922711   484.0
# 698         Ethan Coen     7.0        76731386   321.0
#
# [699 rows x 8 columns]

# %%
director_dataset.to_csv("director_dataset_fin.csv", index=False, encoding='utf-8')

# %%
# Builidng stars dataset

academy_actor = pd.read_csv('acadmey_awards_best_actors.csv')
academy_actoress = pd.read_csv('acadmey_awards_best_actress.csv')
popularity_actor = pd.read_csv('popularity_actors.csv')
popularity_actoress = pd.read_csv('popularity_actress.csv')

# %%
academy_actor['academy_winner'] = 1
academy_actoress['academy_winner'] = 1
academy_actor = academy_actor[['Const','Name','academy_winner']]
academy_actoress = academy_actoress[['Const', 'Name', 'academy_winner']]

# %%
academy_stars = pd.merge(academy_actor, academy_actoress,how='outer')
academy_stars
# Out:
#          Const              Name  academy_winner
# 0    nm0417837     Emil Jannings               1
# 1    nm0062828     Warner Baxter               1
# 2    nm0002183     George Arliss               1
# 3    nm0000859  Lionel Barrymore               1
# 4    nm0545298     Fredric March               1
# ..         ...               ...             ...
# 155  nm0000194    Julianne Moore               1
# 156  nm0488953       Brie Larson               1
# 157  nm1297015        Emma Stone               1
# 158  nm1469236     Olivia Colman               1
# 159  nm0000250   Ren�e Zellweger               1
#
# [160 rows x 3 columns]

# %%
popularity_actor = popularity_actor[['Const', 'Description','Name']]
popularity_actoress = popularity_actoress[['Const', 'Description','Name']]

# %%
popularity_stars = pd.merge(popularity_actor,popularity_actoress, how = 'outer')
popularity_stars
# Out:
#           Const    Description                  Name
# 0     nm0000151  167820 points        Morgan Freeman
# 1     nm0000093  160473 points             Brad Pitt
# 2     nm0000138  157865 points     Leonardo DiCaprio
# 3     nm0000134  151313 points        Robert De Niro
# 4     nm0000354  140716 points            Matt Damon
# ...         ...            ...                   ...
# 1484  nm0726257     507 points         Katja Riemann
# 1485  nm0461746     507 points  Sidse Babett Knudsen
# 1486  nm0937557     502 points       Johanna Wokalek
# 1487  nm0880167     502 points             Nadja Uhl
# 1488  nm0637649     501 points           Magali No�l
#
# [1489 rows x 3 columns]

# %%
stars_power = pd.merge(popularity_stars,academy_stars, how = 'outer')
stars_power
# Out:
#           Const    Description               Name  academy_winner
# 0     nm0000151  167820 points     Morgan Freeman             NaN
# 1     nm0000093  160473 points          Brad Pitt             NaN
# 2     nm0000138  157865 points  Leonardo DiCaprio             1.0
# 3     nm0000134  151313 points     Robert De Niro             1.0
# 4     nm0000354  140716 points         Matt Damon             NaN
# ...         ...            ...                ...             ...
# 1513  nm0536167            NaN       Anna Magnani             1.0
# 1514  nm0001333            NaN      Susan Hayward             1.0
# 1515  nm0413559            NaN     Glenda Jackson             1.0
# 1516  nm0656183            NaN     Geraldine Page             1.0
# 1517  nm0559144            NaN      Marlee Matlin             1.0
#
# [1518 rows x 4 columns]

# %%
stars_power.fillna(0,inplace=True)

# %%
stars_power['Description'] =  stars_power['Description'].astype('str').apply(extract_num).astype('int')
stars_power.rename(columns={"Description":"popularity_point_stars"},inplace=True)
stars_power.columns = ['const','stars_popularity_point','name','star_academy_winner']
stars_power = stars_power[['const','name','star_academy_winner','stars_popularity_point']]
stars_power.to_csv("stars_power_fin_dataset.csv", index=False, encoding='utf-8')
stars_power
# Out:
#           const               name  star_academy_winner  \
# 0     nm0000151     Morgan Freeman                  0.0
# 1     nm0000093          Brad Pitt                  0.0
# 2     nm0000138  Leonardo DiCaprio                  1.0
# 3     nm0000134     Robert De Niro                  1.0
# 4     nm0000354         Matt Damon                  0.0
# ...         ...                ...                  ...
# 1513  nm0536167       Anna Magnani                  1.0
# 1514  nm0001333      Susan Hayward                  1.0
# 1515  nm0413559     Glenda Jackson                  1.0
# 1516  nm0656183     Geraldine Page                  1.0
# 1517  nm0559144      Marlee Matlin                  1.0
#
#       stars_popularity_point
# 0                     167820
# 1                     160473
# 2                     157865
# 3                     151313
# 4                     140716
# ...                      ...
# 1513                       0
# 1514                       0
# 1515                       0
# 1516                       0
# 1517                       0
#
# [1518 rows x 4 columns]

# %% [markdown]
# # 4. Collecting data from tmdb
# I used tmdb api to get the popularity, budget, renvenue of movies
#
#
# #### Data soruce:
# - https://developers.themoviedb.org/3
# - https://github.com/AnthonyBloomer/tmdbv3api(for python)

# %%
# !pip install tmdbv3api

# %%
import tmdbv3api
from tmdbv3api import Movie, TMDb, Discover
from time import sleep
import pandas as pd

tmdb = TMDb()
find = Find()
movie = Movie()
tmdb.api_key = '661052c4310481678e97187e9cbf003f'
tmdb.language = 'en'

# %%
imdb_data = pd.read_csv("Fin_dataset/imdb_combined_data.csv",encoding='CP949')
imdb_data.head()

# %%
movie_title = []
tmdb_id = []

for i in range(0, len(imdb_data.imdb_title_id)):
    
    if i % 500 == 0:
        
        results = find.find_by_imdb_id(imdb_data.imdb_title_id[i])
        for r in results["movie_results"]:
            movie_title.append(r.title)
            tmdb_id.append(r.id)
    
            sleep(2)
            
    else:
        
        results = find.find_by_imdb_id(imdb_data.imdb_title_id[i])
        for r in results["movie_results"]:
            movie_title.append(r.title)
            tmdb_id.append(r.id)

# %%
tmdb_id = pd.DataFrame({"Movie_tmdb_id":tmdb_id, "Title":movie_title})

# %%
movie = Movie()

tmdb_id_1 = []
original_title=[]
budget=[]
imdb_id=[]
popularity=[]
revenue = []

for m in range(0, len(tmdb_id)):

    if m % 100 == 0:
        d = movie.details(tmdb_id[m])
        
        tmdb_id_1.append(tmdb_id[m])
        original_title.append(d.title)
        budget.append(d.budget)
        imdb_id.append(d.imdb_id)
        popularity.append(d.popularity)
        revenue.append(d.revenue)
        print("Finshed:",m,"Sucess:","{0:0.2f}%".format((m/len(tmdb_id))*100),"10 Sec Delay")
        sleep(10)
        
    else:
        
        d = movie.details(tmdb_id[m])
        
        tmdb_id_1.append(tmdb_id[m])
        original_title.append(d.title)
        budget.append(d.budget)
        imdb_id.append(d.imdb_id)
        popularity.append(d.popularity)
        revenue.append(d.revenue)
        print("Finshed:",m,"Sucess:","{0:0.2f}%".format((m/len(tmdb_id))*100))

# %%
Movie_2021 = pd.DataFrame({"tmdb_id": tmdb_id_1, "Movie_imdb_id": imdb_id, "Title":original_title,
                           "Movie_budget": budget, "Movie_Popularity": popularity, "Movie_renvenue":revenue})

# %%
Movie_2021.to_csv("tmdb_dataset_fin.csv",index=False)
